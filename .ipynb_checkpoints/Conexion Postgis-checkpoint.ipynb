# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import psycopg2
import contextily as cx
import matplotlib.pyplot as plt
import folium
import datetime
from datetime import date, timedelta
import locale

# %%
locale.setlocale(locale.LC_ALL, 'es-ES')
# Out:
# 'es-ES'

# %%
dia_actual = date.today()
ayer = dia_actual - timedelta(days = 1)
ayer_str = ayer.strftime("%A %d de %B de %Y")
ayer_str
# Out:
# 'viernes 12 de agosto de 2022'

# %%
con = psycopg2.connect(database= "ideam", user="fda_ideam", password= "Fd4_1d34m201902",
    host = "172.16.1.193")
con_2 = psycopg2.connect(database= "tabla_manipulada", user="postgres", password= "Septiembre0672",
    host = "localhost")

# %%
fecha_anterior = ayer.strftime("%Y-%m-%d")
fecha_anterior

fecha_actual = dia_actual.strftime("%Y-%m-%d")

# %%
sql = f''' SELECT st.station_name, st.municipality, st.province, ad.id_stz, SUM(ad.raw_data) AS precipitacion, st.the_geom,
            ST_X(st.the_geom), ST_Y(st.the_geom)
            FROM data_radio.archive_data AS ad INNER JOIN configuration.stations AS st
                ON ad.id_stz = st.id_stz
            WHERE id_measure = 1
            AND ad.date_record BETWEEN '{fecha_anterior} 07:0:00.000'::timestamp AND  '{fecha_actual} 07:0:00.000'::timestamp
            GROUP BY ad.id_stz, st.station_name, st.municipality, st.province, ad.id_stz, st.the_geom
            HAVING SUM(ad.raw_data) between 0 AND 300 
            ORDER BY precipitacion DESC NULLS LAST; '''

# %%
departamentos = '''SELECT * FROM base.departamentos'''

# %%
df_departamentos = gpd.GeoDataFrame.from_postgis(departamentos, con_2, geom_col = 'geom', crs = "EPSG:4326")

# %%
estaciones = gpd.GeoDataFrame.from_postgis(sql, con, geom_col = 'the_geom', crs = "EPSG:4326")

# %%
estaciones.plot()
# Out:
# <AxesSubplot:>

# %%
estaciones.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# ax = df.plot(figsize=(15, 15), alpha = 1, edgecolor='k', color = 'y', markersize = df["precipitacion"] * 10 )
# cx.add_basemap(ax, crs = df.crs, source=cx.providers.CartoDB.Voyager)

# %%
# colombia = df_departamentos.explore(m = estaciones, )
# df.explore(m = colombia, marker_kwds = {'radius': 4}, scheme = 'naturalbreaks', column = 'precipitacion', cmap = 'Set1', tiles="Open Street Map")

# %%
plt.style.use('bmh')
fig, (ax, ax2) = plt.subplots(figsize = (22, 9), nrows = 1, ncols = 2)

df_departamentos.plot(ax = ax, color = "#D3EEBF", edgecolor = "black", alpha = 0.5)
estaciones.plot(ax = ax, scheme = 'NaturalBreaks', column = 'precipitacion', cmap = 'rainbow', legend = True)
ax.set_title(f'Mapa precipitación estaciones automáticas \n Día meteorológico \n {fecha_anterior}')
ax2.set_title(f'Top 15 mayores lluvias \n {fecha_anterior}')
ax2.barh(estaciones['municipality'].head(15), estaciones['precipitacion'].head(15), color = ['y' if x == estaciones['precipitacion'].max() else '#41929F' for x in estaciones['precipitacion']])
ax2.set_xlabel('Precipitación (mm)')
ax2.grid(visible = True)
cx.add_basemap(ax, crs = df_departamentos.crs, source=cx.providers.CartoDB.Voyager)

# %%
estaciones.head(20)
# Out:
#                                          station_name  \
# 0   LA MOJANA: CHINU [0025020470; COR; MET; AOXX; ...
# 1   PTE. LLERAS [35017020; MET; HID; LG; R; AO03; ...
# 2   VILLAVICENCIO SEDE IDEAM -ICA [35035100; MET; ...
# 3   PUERTO INIRIDA - AUT [0031095030; GUA; MET; OT...
# 4   SALINAS DE UPIN [35035110; MET; MET; AM; R; AO...
# 5   CARACOLI  [2802500079; CES; MET; CP; N; AO05; ...
# 6   VIZCAINA [24055080; SAN; MET; AM; R; AO08; H7;...
# 7   LA MOJANA: MARRALU [0025027770; COR; HID; AOXX...
# 8   LA GRAN VIA [29065130; MAG; MET; AM; R; AO05; ...
# 9   GUAYURIBA [3502700090; MET; HID; ST; N; AO03; ...
# 10  LA MOJANA: AYAPEL [0025025030; COR; MET; AOXX;...
# 11  PR CHOCO: BELLAVISTA [11080010; CHO; MET; SUB;...
# 12  PERENCO: TAMARA [35235050; CAS; MET; CO; AO06;...
# 13  PIJAO [2612500124; QUI; MET; ST; N; AO09; H6; ...
# 14  LA MOJANA: SAN BENITO [0025025380; SUC; MET; A...
# 15  GUAYABETAL POLLO OLIMPICO [3502500135; CUN; ME...
# 16  LA GALERA [26217010; ANT; HID; ST; ROC; AO01; ...
# 17  LOS ALAMOS [0025025002; MAG; MET; OTT; GOES: C...
# 18  APTO ALFONSO LOPEZ [0028025502; CES; MET; XX; ...
# 19  NATAIMA [21185090; TOL; MET; CP; R; AO10; H2; ...
#
#                    municipality      province  id_stz  precipitacion  \
# 0                         Chinu                  1948         101.70
# 1                  Puerto López          Meta     161          76.20
# 2                 Villavicencio          Meta      82          74.50
# 3                       Inírida                  1135          65.90
# 4                      Restrepo          Meta     178          65.70
# 5                      Bosconia         Cesar     315          64.00
# 6               Barrancabermeja     Santander     243          61.50
# 7                        Ayapel                  1941          56.20
# 8                 Zona Bananera     Magdalena      75          53.90
# 9                  Puerto López          Meta     280          49.40
# 10                       Ayapel                  1943          48.30
# 11                        Chocó         Chocó    1652          44.70
# 12                       Tamara      Casanare    1511          43.70
# 13                        Pijao       Quindio     421          41.00
# 14                   San Benito                  1942          38.10
# 15                   Guayabetal  Cundinamarca    1154          33.30
# 16        Santa fé de Antioquia     Antioquia     181          31.20
# 17  San Sebastian de Buenavista     Magdalena    1158          29.00
# 18                                               1993          28.56
# 19                      Espinal        Tolima     116          26.40
#
#                       the_geom       st_x       st_y
# 0    POINT (-75.39333 9.11778) -75.393333   9.117778
# 1    POINT (-72.93633 4.10302) -72.936330   4.103020
# 2    POINT (-73.62505 4.13722) -73.625050   4.137220
# 3    POINT (-67.93169 3.86767) -67.931694   3.867667
# 4    POINT (-73.58792 4.27327) -73.587920   4.273270
# 5   POINT (-73.73167 10.08869) -73.731667  10.088694
# 6    POINT (-73.70489 6.98297) -73.704889   6.982972
# 7    POINT (-75.23925 8.30592) -75.239250   8.305917
# 8   POINT (-74.13781 10.85064) -74.137806  10.850639
# 9    POINT (-73.27113 3.95811) -73.271131   3.958114
# 10   POINT (-75.16456 8.29506) -75.164556   8.295064
# 11   POINT (-76.88810 6.55690) -76.888100   6.556900
# 12   POINT (-72.16678 5.81858) -72.166778   5.818583
# 13   POINT (-75.68414 4.33136) -75.684139   4.331361
# 14   POINT (-75.03728 8.93512) -75.037276   8.935115
# 15   POINT (-73.81262 4.22967) -73.812625   4.229669
# 16   POINT (-75.86430 6.55490) -75.864300   6.554900
# 17   POINT (-74.27364 9.30406) -74.273639   9.304056
# 18  POINT (-73.24767 10.43617) -73.247667  10.436167
# 19   POINT (-74.95950 4.18761) -74.959500   4.187611

# %%
fig = plt.figure(figsize = (15,20))
ax3 = fig.gca()
estaciones.hist(ax = ax3, column='precipitacion', by = 'province')
plt.show()
# Out:
# C:\Users\easalazarm\Anaconda3\envs\geo\lib\site-packages\pandas\plotting\_matplotlib\hist.py:428: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   **kwds,

# %%
estaciones.columns
# Out:
# Index(['station_name', 'municipality', 'province', 'id_stz', 'precipitacion',
#        'the_geom', 'st_x', 'st_y'],
#       dtype='object')

# %%
estaciones_gis = estaciones[['station_name', 'municipality', 'province', 'precipitacion', 'st_x', 'st_y']]
estaciones_gis
# Out:
#                                           station_name   municipality  \
# 0    LA MOJANA: CHINU [0025020470; COR; MET; AOXX; ...          Chinu
# 1    PTE. LLERAS [35017020; MET; HID; LG; R; AO03; ...   Puerto López
# 2    VILLAVICENCIO SEDE IDEAM -ICA [35035100; MET; ...  Villavicencio
# 3    PUERTO INIRIDA - AUT [0031095030; GUA; MET; OT...        Inírida
# 4    SALINAS DE UPIN [35035110; MET; MET; AM; R; AO...       Restrepo
# ..                                                 ...            ...
# 283  LA MOJANA: SAN PEDRO [0025020440; SUC; MET; AO...      San pedro
# 284  APTO SAN LUIS [0052055230; NAR; MET; XX; AO; G...       Riohacha
# 285  APTO VASQUEZ COBO [0048015050; AMA; MET; XX; A...
# 286  APTO PALONEGRO [0023195502; SAN; MET; XX; AO; ...
# 287  APTO LOS GARZONES [0013035501; COR; MET; XX; A...
#
#     province  precipitacion       st_x      st_y
# 0                     101.7 -75.393333  9.117778
# 1       Meta           76.2 -72.936330  4.103020
# 2       Meta           74.5 -73.625050  4.137220
# 3                      65.9 -67.931694  3.867667
# 4       Meta           65.7 -73.587920  4.273270
# ..       ...            ...        ...       ...
# 283                     0.0 -75.016389  9.401639
# 284                     0.0 -77.677750  0.857083
# 285                     0.0 -69.940917 -4.193861
# 286                     0.0 -73.184528  7.121472
# 287                     0.0 -75.825139  8.825833
#
# [288 rows x 6 columns]

# %%
estaciones_gis.to_excel(fr"C:\Users\easalazarm\Documents\IDEAM\IDEAM\Direccion General\Geopandas\Mapas estaciones automaticas\Tablas\precipitacion_24h.xls", index = False)
# Out:
# C:\Users\easalazarm\Anaconda3\envs\geo\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.
